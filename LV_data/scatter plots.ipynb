# %%
import numpy as np
import pandas as pd
import xlrd
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches


xl = pd.ExcelFile('LV_data_Krell_study.xlsx') # loading spreadsheet
print(xl.sheet_names) # printing sheet name
df1 = xl.parse('Tabelle1') # loading sheet into dataframe
print(df1.shape)
df1.head()
# Out:
# ['Tabelle1']
# (353, 11)
#   Patienten-ID Gender    Age  Weight  Height   ESV    EDV    SV    EF  \
# 0         BONN    NaN    NaN     NaN     NaN   NaN    NaN   NaN   NaN
# 1         5002      1   37.0    13.5    98.0   9.1   23.4  14.3  61.2
# 2         5003      2  158.0    30.0   139.0  34.0   87.3  53.3  61.0
# 3         5004      1  186.0    46.0   162.0  38.7  118.6  79.9  67.4
# 4         5005      2   83.0    24.5   118.0  20.5   55.5  35.0  63.0
#
#    Herzfrequenz  Körperoberfläche nach Haycock
# 0           NaN                            NaN
# 1         108.0                       0.605614
# 2          89.0                       1.068728
# 3          81.0                       1.429102
# 4          81.0                       0.898189

# %%
df1.describe()
# Out:
#               Age      Weight      Height         ESV         EDV          SV  \
# count  350.000000  350.000000  350.000000  352.000000  352.000000  352.000000
# mean    96.659171   31.402657  126.598286   26.898892   68.752557   41.949290
# std     60.917193   19.345636   35.719935   15.774989   39.737879   24.853472
# min      0.030000    2.160000   40.000000    0.000000    0.000000    0.000000
# 25%     47.000000   16.250000  102.000000   15.000000   39.637500   24.275000
# 50%     93.000000   26.500000  130.000000   25.000000   62.050000   36.750000
# 75%    146.000000   45.000000  157.000000   37.925000   95.800000   58.600000
# max    219.000000   92.700000  192.000000   72.500000  239.900000  168.300000
#
#                EF  Herzfrequenz  Körperoberfläche nach Haycock
# count  352.000000    350.000000                     350.000000
# mean    61.090341     90.602857                       1.036917
# std      6.906179     22.977614                       0.473118
# ...

# %%
df1.plot.bar()
plt.rcParams["figure.figsize"] = (100,60) # changing figure size

# %%
plt.figure(figsize=(7,7))
plt.scatter(df1['Age'],df1['ESV'])
plt.xlabel('Age')
plt.ylabel('ESV')
# Out:
# Text(0,0.5,'ESV')

# %%
plt.figure(figsize=(7,7))
plt.scatter(df2['Age'],df2['ESV'])
plt.xlabel('Age')
plt.ylabel('ESV')
# Out:
# Text(0,0.5,'ESV')

# %%
fig, ax = plt.subplots()
ax.scatter( x= df1["Weight"], y = df1["ESV"],color = 'red',label = 'ESV')
ax.scatter( x= df1["Weight"], y = df1['EDV'],color = 'blue',label = 'EDV')
ax.scatter( x= df1["Weight"], y = df1['SV'], color = 'green', label = 'SV')
ax.scatter( x= df1["Weight"], y = df1['EF'], color = 'black', label = 'EF')
ax.scatter( x= df1["Weight"], y = df1['Herzfrequenz'], color = 'orange', label = 'Herzfrequenz')
plt.xlabel('Weight')
plt.ylabel(('ESV','EDV','EF','SV','Herzfrequenz'))
plt.legend()
plt.show()
# Get current size
fig_size = plt.rcParams["figure.figsize"]
print(fig_size) #100, 60
# Set figure width to 12 and height to 9
fig_size[0] = 20
fig_size[1] = 10
#plt.rcParams["figure.figsize"] = fig_size


## similar is the case of weight to the age
# Out:
# [20, 10]

# %%
fig, ax = plt.subplots()
ax.scatter( x= df1["Height"], y = df1["ESV"],color = 'red',label = 'ESV')
ax.scatter( x= df1["Height"], y = df1['EDV'],color = 'blue',label = 'EDV')
ax.scatter( x= df1["Height"], y = df1['SV'], color = 'green', label = 'SV')
ax.scatter( x= df1["Height"], y = df1['EF'], color = 'black', label = 'EF')
ax.scatter( x= df1["Height"], y = df1['Herzfrequenz'], color = 'orange', label = 'Herzfrequenz')
plt.xlabel('Height')
plt.ylabel(('ESV','EDV','EF','SV','Herzfrequenz'))
plt.legend()
plt.show()
# Get current size
fig_size = plt.rcParams["figure.figsize"]
print(fig_size) #100, 60
# Set figure width to 12 and height to 9
fig_size[0] = 20
fig_size[1] = 10
#plt.rcParams["figure.figsize"] = fig_size


## similar is the case of Height to the age
# Out:
# [20, 10]

# %%
fig, ax = plt.subplots()
ax.scatter( x= df1["Age"], y = df1["ESV"],color = 'red',label = 'ESV')
ax.scatter( x= df1["Age"], y = df1['EDV'],color = 'blue',label = 'EDV')
ax.scatter( x= df1["Age"], y = df1['SV'], color = 'green', label = 'SV')
ax.scatter( x= df1["Age"], y = df1['EF'], color = 'black', label = 'EF')
ax.scatter( x= df1["Age"], y = df1['Herzfrequenz'], color = 'orange', label = 'Herzfrequenz')
plt.xlabel('Age')
plt.ylabel(('ESV','EDV','EF','SV','Herzfrequenz'))
plt.legend()
plt.show()
# Get current size
fig_size = plt.rcParams["figure.figsize"]
print(fig_size) #100, 60
# Set figure width to 12 and height to 9
fig_size[0] = 20
fig_size[1] = 10
#plt.rcParams["figure.figsize"] = fig_size

##ESV, EDV ,SV seems directly proportional with age
## EF slighlty proportional
## Herzfrequenz inversely proportional
# Out:
# [20, 10]

# %%
fig, ax = plt.subplots()
ax.scatter( x= df1["ESV"], y = df1['EDV'],color = 'blue',label = 'EDV')
ax.scatter( x= df1["ESV"], y = df1['SV'], color = 'green', label = 'SV')
ax.scatter( x= df1["ESV"], y = df1['EF'], color = 'black', label = 'EF')
ax.scatter( x= df1["ESV"], y = df1['Herzfrequenz'], color = 'orange', label = 'Herzfrequenz')
plt.xlabel('ESV')
plt.ylabel(('EDV','EF','SV','Herzfrequenz'))
plt.legend()
plt.show()
# Get current size
fig_size = plt.rcParams["figure.figsize"]
print(fig_size) #100, 60
# Set figure width to 12 and height to 9
fig_size[0] = 20
fig_size[1] = 10
#plt.rcParams["figure.figsize"] = fig_size

## EDV ,SV seems directly proportional with ESV
## EF almost staright slightly inversely proportional
## Herzfrequenz inversely proportional
# Out:
# [20, 10]

# %%
fig, ax = plt.subplots()
ax.scatter( x= df1["EDV"], y = df1["ESV"],color = 'red',label = 'ESV')
ax.scatter( x= df1["EDV"], y = df1['SV'], color = 'green', label = 'SV')
ax.scatter( x= df1["EDV"], y = df1['EF'], color = 'black', label = 'EF')
ax.scatter( x= df1["EDV"], y = df1['Herzfrequenz'], color = 'orange', label = 'Herzfrequenz')
plt.xlabel('EDV')
plt.ylabel(('ESV','EF','SV','Herzfrequenz'))
plt.legend()
plt.show()
# Get current size
fig_size = plt.rcParams["figure.figsize"]
print(fig_size) #100, 60
# Set figure width to 12 and height to 9
fig_size[0] = 20
fig_size[1] = 10
#plt.rcParams["figure.figsize"] = fig_size

##ESV,SV seems directly proportional with age
## EF almost straight
## Herzfrequenz inversely proportional
# Out:
# [20, 10]

# %%
fig, ax = plt.subplots()
ax.scatter( x= df1["SV"], y = df1["ESV"],color = 'red',label = 'ESV')
ax.scatter( x= df1["SV"], y = df1['EDV'],color = 'blue',label = 'EDV')
ax.scatter( x= df1["SV"], y = df1['EF'], color = 'black', label = 'EF')
ax.scatter( x= df1["SV"], y = df1['Herzfrequenz'], color = 'orange', label = 'Herzfrequenz')
plt.xlabel('SV')
plt.ylabel(('ESV','EDV','EF','Herzfrequenz'))
plt.legend()
plt.show()
# Get current size
fig_size = plt.rcParams["figure.figsize"]
print(fig_size) #100, 60
# Set figure width to 12 and height to 9
fig_size[0] = 20
fig_size[1] = 10
#plt.rcParams["figure.figsize"] = fig_size

##ESV, EDV seems directly proportional with age
## EF almost straight
## Herzfrequenz inversely proportional
# Out:
# [20, 10]

# %%
fig, ax = plt.subplots()
ax.scatter( x= df1["EF"], y = df1["ESV"],color = 'red',label = 'ESV')
ax.scatter( x= df1["EF"], y = df1['EDV'],color = 'blue',label = 'EDV')
ax.scatter( x= df1["EF"], y = df1['SV'], color = 'green', label = 'SV')
ax.scatter( x= df1["EF"], y = df1['Herzfrequenz'], color = 'orange', label = 'Herzfrequenz')
plt.xlabel('EF')
plt.ylabel(('ESV','EDV','SV','Herzfrequenz'))
plt.legend()
plt.show()
# Get current size
fig_size = plt.rcParams["figure.figsize"]
print(fig_size) #100, 60
# Set figure width to 12 and height to 9
fig_size[0] = 20
fig_size[1] = 10
#plt.rcParams["figure.figsize"] = fig_size

## cant be explained
# Out:
# [20, 10]

# %%
fig, ax = plt.subplots()
ax.scatter( x= df1["Herzfrequenz"], y = df1["ESV"],color = 'red',label = 'ESV')
ax.scatter( x= df1["Herzfrequenz"], y = df1['EDV'],color = 'blue',label = 'EDV')
ax.scatter( x= df1["Herzfrequenz"], y = df1['SV'], color = 'green', label = 'SV')
ax.scatter( x= df1["Herzfrequenz"], y = df1['EF'], color = 'black', label = 'EF')
plt.xlabel('Herzfrequenz')
plt.ylabel(('ESV','EDV','EF','SV',))
plt.legend()
plt.show()
# Get current size
fig_size = plt.rcParams["figure.figsize"]
print(fig_size) #100, 60
# Set figure width to 12 and height to 9
fig_size[0] = 20
fig_size[1] = 10
#plt.rcParams["figure.figsize"] = fig_size

##ESV, EDV ,SV seems indirectly proportional with age
## EF almost straight
# Out:
# [20, 10]

# %%
plt.hist(df1.Age.dropna(),25)
# Out:
# (array([33.,  9., 12., 14., 13., 20., 15., 20., 15., 14., 16., 16., 10.,
#         13., 17., 14., 14., 12., 13., 15., 12., 13.,  9.,  8.,  3.]),
#  array([3.000000e-02, 8.788800e+00, 1.754760e+01, 2.630640e+01,
#         3.506520e+01, 4.382400e+01, 5.258280e+01, 6.134160e+01,
#         7.010040e+01, 7.885920e+01, 8.761800e+01, 9.637680e+01,
#         1.051356e+02, 1.138944e+02, 1.226532e+02, 1.314120e+02,
#         1.401708e+02, 1.489296e+02, 1.576884e+02, 1.664472e+02,
#         1.752060e+02, 1.839648e+02, 1.927236e+02, 2.014824e+02,
#         2.102412e+02, 2.190000e+02]),
#  <a list of 25 Patch objects>)

# %%
y1 = df1['Age']
y2 = df1['Weight']
x = np.arange(len(y1))
#x = df1['Gender']
bar_width = 1
plt.bar(x,y1,width = bar_width, color = 'green',zorder = 2)
plt.bar(x+bar_width,y2,width = bar_width, color = 'red',zorder = 2)

#plt.xticks(x+bar_width*2,['Age','Width'])

green_patch = mpatches.Patch(color = 'green', label = 'Age')
red_patch = mpatches.Patch(color = 'red', label = 'Weight')

plt.legend(handles = [green_patch,red_patch])
plt.grid(axis = y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-202d1b82890c> in <module>()
#      13
#      14 plt.legend(handles = [green_patch,red_patch])
# ---> 15 plt.grid(axis = y)
#      16 plt.show()
#
# NameError: name 'y' is not defined

# %%
tmp=list(df1.groupby("Gender"))
df1_gender1=tmp[0][1]
df1_gender2=tmp[1][1]

# %%
df1_gender1
# Out:
#     Patienten-ID Gender     Age  Weight  Height    ESV     EDV     SV     EF  \
# 1           5002      1   37.00   13.50    98.0   9.10   23.40  14.30  61.20
# 3           5004      1  186.00   46.00   162.0  38.70  118.60  79.90  67.40
# 6           5007      1   22.00   11.20    81.0   6.00   23.60  17.60  74.80
# 7           5008      1   50.00   15.00   102.0  10.40   30.35  19.95  66.25
# 13          5014      1   90.00   22.00   124.0  23.40   56.00  32.50  58.10
# 14          5015      1   67.00   48.00   105.0  10.90   36.30  25.40  70.00
# 20          5021      1  209.00   49.00   163.0  43.90  108.60  64.70  59.60
# 21          5023      1   55.00   14.50    98.0  20.10   44.10  24.00  54.50
# 24          5030      1  144.00   37.00   152.0  35.50   84.50  49.00  58.00
# 25          5031      1  191.00   66.90   168.5  51.00  127.20  76.20  59.90
# 26          5032      1  179.00   60.20   171.0  40.70  136.40  95.60  70.10
# ...
